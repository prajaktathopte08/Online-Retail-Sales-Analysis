# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/admin/Documents/Prajakta/Python/Projects/Libraries Project/Retail Analysis.csv")

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# <!-- Data Cleaning -->

# %%
data.shape
# Out:
# (541909, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# Drop blank Rows
data = data.dropna(subset=["CustomerID"])

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# Find the mode of Description
mode_description = data["Description"].mode()[0]
mode_description
# Out:
# 'WHITE HANGING HEART T-LIGHT HOLDER'

# %%
# Replace missing values with mode
data["Description"].fillna(mode_description, inplace=True)
# Out:
# c:\Users\admin\anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
data.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
#  Remove Invalid Quantity & Price
data = data[data["Quantity"] > 0]
data = data[data["UnitPrice"] > 0]
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397884 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397884 non-null  object
#  1   StockCode    397884 non-null  object
#  2   Description  397884 non-null  object
#  3   Quantity     397884 non-null  int64
#  4   InvoiceDate  397884 non-null  object
#  5   UnitPrice    397884 non-null  float64
#  6   CustomerID   397884 non-null  float64
#  7   Country      397884 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 27.3+ MB

# %%
# Remove leading & trailing spaces
data["Description"] = data["Description"].str.strip()

# %%
# Create Total Sales Col
data["TotalSales"] = data["Quantity"] * data["UnitPrice"]
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  TotalSales
# ...

# %%
# Convert InvoiceDate to Datetime
data["InvoiceDate"] = pd.to_datetime(data["InvoiceDate"])

# Extract Date Features
data["Year"] = data["InvoiceDate"].dt.year
data["Month"] = data["InvoiceDate"].dt.month
data["Day"] = data["InvoiceDate"].dt.day

# %% [markdown]
# # Find patterns trend

# %%
# Monthly Sales Trend
monthly_sales = data.groupby("Month")["TotalSales"].sum()
monthly_sales


# Monthly Sales Trend

monthly_sales.plot(kind="line", marker="o")
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()

# %%
# Top 10 Selling Products
top_products = data.groupby("Description")["Quantity"].sum().sort_values(ascending=False).head(10)

top_products.plot(kind="barh")
# Out:
# <AxesSubplot:ylabel='Description'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397884 entries, 0 to 541908
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397884 non-null  object
#  1   StockCode    397884 non-null  object
#  2   Description  397884 non-null  object
#  3   Quantity     397884 non-null  int64
#  4   InvoiceDate  397884 non-null  datetime64[ns]
#  5   UnitPrice    397884 non-null  float64
#  6   CustomerID   397884 non-null  float64
#  7   Country      397884 non-null  object
#  8   TotalSales   397884 non-null  float64
#  9   Year         397884 non-null  int64
#  10  Month        397884 non-null  int64
#  11  Day          397884 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(4)
# memory usage: 39.5+ MB

# %%
# Calculate 10 country-wise sales.
Top_10 = (
    data.groupby("Country")["TotalSales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

plt.figure(figsize=(10, 5))

sns.barplot(
    data=Top_10,
    x="Country",
    y="TotalSales",
    palette="viridis"
)

plt.title("Country Wise Total Sales")
plt.xlabel("Country")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %%
# Top 10 Customer Analysis
top_customers = data.groupby("CustomerID")["TotalSales"].sum().sort_values(ascending=False).head(10)

top_customers
# Out:
# CustomerID
# 14646.0    280206.02
# 18102.0    259657.30
# 17450.0    194550.79
# 16446.0    168472.50
# 14911.0    143825.06
# 12415.0    124914.53
# 14156.0    117379.63
# 17511.0     91062.38
# 16029.0     81024.84
# 12346.0     77183.60
# Name: TotalSales, dtype: float64

# %%
# Calculate Frequency.
data.groupby("CustomerID")["InvoiceNo"].count()
# Out:
# CustomerID
# 12346.0      1
# 12347.0    182
# 12348.0     31
# 12349.0     73
# 12350.0     17
#           ...
# 18280.0     10
# 18281.0      7
# 18282.0     12
# 18283.0    756
# 18287.0     70
# Name: InvoiceNo, Length: 4338, dtype: int64

# %%
# Plot top 5 countries by sales.
country_sales = data.groupby("Country")["TotalSales"].sum().nlargest(5)
sns.barplot(x=country_sales.values, y=country_sales.index)
plt.show()

# %%
# Find top 10 customers by revenue.
data.groupby("CustomerID")["TotalSales"].sum().sort_values(ascending=False).head(10)
# Out:
# CustomerID
# 14646.0    280206.02
# 18102.0    259657.30
# 17450.0    194550.79
# 16446.0    168472.50
# 14911.0    143825.06
# 12415.0    124914.53
# 14156.0    117379.63
# 17511.0     91062.38
# 16029.0     81024.84
# 12346.0     77183.60
# Name: TotalSales, dtype: float64

# %%
# Count number of orders per customer.
data.groupby("CustomerID")["InvoiceNo"].nunique()
# Out:
# CustomerID
# 12346.0     1
# 12347.0     7
# 12348.0     4
# 12349.0     1
# 12350.0     1
#            ..
# 18280.0     1
# 18281.0     1
# 18282.0     2
# 18283.0    16
# 18287.0     3
# Name: InvoiceNo, Length: 4338, dtype: int64

# %%
# Find average order value per customer.
data.groupby("CustomerID")["TotalSales"].mean()
# Out:
# CustomerID
# 12346.0    77183.600000
# 12347.0       23.681319
# 12348.0       57.975484
# 12349.0       24.076027
# 12350.0       19.670588
#                ...
# 18280.0       18.060000
# 18281.0       11.545714
# 18282.0       14.837500
# 18283.0        2.771005
# 18287.0       26.246857
# Name: TotalSales, Length: 4338, dtype: float64
